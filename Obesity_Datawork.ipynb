# %% [markdown]
# # Obesity Data Analysis

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm 
from scipy import stats
from math import comb, factorial
sns.set()

# %%
Data = pd.read_csv('Obesity_Dataset.csv')
Data
# Out:
#       Sex  Age  Height  Overweight_Obese_Family  Consumption_of_Fast_Food  \
# 0       2   18     155                        2                         2
# 1       2   18     158                        2                         2
# 2       2   18     159                        2                         2
# 3       2   18     162                        2                         2
# 4       2   18     165                        2                         1
# ...   ...  ...     ...                      ...                       ...
# 1605    2   51     165                        2                         1
# 1606    2   51     163                        2                         1
# 1607    2   52     162                        1                         2
# 1608    2   53     168                        2                         1
# 1609    2   54     170                        1                         1
#
#       Frequency_of_Consuming_Vegetables  Number_of_Main_Meals_Daily  \
# ...

# %% [markdown]
# ## Inspect Data

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Sex                                1610 non-null   int64
#  1   Age                                1610 non-null   int64
#  2   Height                             1610 non-null   int64
#  3   Overweight_Obese_Family            1610 non-null   int64
#  4   Consumption_of_Fast_Food           1610 non-null   int64
#  5   Frequency_of_Consuming_Vegetables  1610 non-null   int64
#  6   Number_of_Main_Meals_Daily         1610 non-null   int64
#  7   Food_Intake_Between_Meals          1610 non-null   int64
#  8   Smoking                            1610 non-null   int64
#  9   Liquid_Intake_Daily                1610 non-null   int64
#  10  Calculation_of_Calorie_Intake      1610 non-null   int64
# ...

# %%
sns.histplot(Data['Age'], bins=10, kde=True, color='red')
plt.title('Distribution Of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x='Height', y='Age', data=Data, palette='Set3')
plt.show()
# Out:
# C:\Users\ZUBBY WADIS\AppData\Local\Temp\ipykernel_11156\2368756460.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Height', y='Age', data=Data, palette='Set3')

# %%
sns.scatterplot(Data, x='Age', y='Physical_Excercise', palette='coolwarm', hue='Age')
plt.figure(figsize=(10,5))
plt.title('Age vs Physical_Excercise')
plt.xlabel('Age')
plt.ylabel('Physical_Excercise')
plt.show()

# %%
sns.scatterplot(Data, x='Age', y='Number_of_Main_Meals_Daily', palette='coolwarm', hue='Age')
plt.figure(figsize=(10,5))
plt.title('Age vs Number_of_Main_Meals_Daily')
plt.xlabel('Age')
plt.ylabel('Number_of_Main_Meals_Daily')
plt.show()

# %%
sns.scatterplot(Data, x='Age', y='Height', palette='coolwarm', hue='Age')
plt.figure(figsize=(10,5))
plt.title('Age vs Height')
plt.xlabel('Age')
plt.ylabel('Height')
plt.show()

# %%
sns.scatterplot(Data, x='Age', y='Frequency_of_Consuming_Vegetables', palette='coolwarm', hue='Age')
plt.figure(figsize=(10,5))
plt.title('Age vs Frequency_of_Consuming_Vegetables')
plt.xlabel('Age')
plt.ylabel('Frequency_of_Consuming_Vegetables')
plt.show()

# %%
correlation, p_value = stats.pearsonr(Data['Age'], Data['Height'])
correlation, p_value
# Out:
# (0.11549113919394363, 3.384097254254712e-06)

# %%
correlation_matrix = Data.corr()
correlation_matrix
# Out:
#                                         Sex       Age    Height  \
# Sex                                1.000000 -0.182114 -0.690250
# Age                               -0.182114  1.000000  0.115491
# Height                            -0.690250  0.115491  1.000000
# Overweight_Obese_Family            0.068580 -0.161475 -0.165359
# Consumption_of_Fast_Food           0.059621 -0.272612 -0.031478
# Frequency_of_Consuming_Vegetables  0.146067 -0.394701 -0.090057
# Number_of_Main_Meals_Daily         0.044877  0.328642 -0.055054
# Food_Intake_Between_Meals         -0.011508  0.047053 -0.000186
# Smoking                            0.196608 -0.077778 -0.141490
# Liquid_Intake_Daily                0.012885  0.026510 -0.026460
# Calculation_of_Calorie_Intake     -0.027745 -0.203458 -0.029721
# Physical_Excercise                -0.086369  0.337484  0.076698
# Schedule_Dedicated_to_Technology  -0.005656 -0.254816  0.001916
# Type_of_Transportation_Used        0.028805 -0.689950 -0.003872
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(Data.corr(), annot=True, cmap='coolwarm', annot_kws={'size':10},
xticklabels={'size':14},
yticklabels={'size':14})
plt.title('Correlation heatmap')
plt.show()

# %%
X = Data['Age']
Y = Data['Height']

# %%
X = sm.add_constant(X)

model = sm.OLS(Y,X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Height   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     21.74
# Date:                Mon, 30 Sep 2024   Prob (F-statistic):           3.38e-06
# Time:                        13:32:18   Log-Likelihood:                -5617.0
# No. Observations:                1610   AIC:                         1.124e+04
# Df Residuals:                    1608   BIC:                         1.125e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        164.6385      0.694    237.135      0.000     163.277     166.000
# ...

# %%
X = Data['Age']
Y = Data['Height']

beta_0 = 164.6385 #(Inercept)
beta_1 = 0.0937 #(Slope)

y_pred = beta_0 + beta_1*X

sns.scatterplot(x = X, y=Y)
plt.title('Age Vs. Height')

plt.plot(X, y_pred, color = 'red', label = 'Trendline')

plt.legend()

plt.xlabel('Age')
plt.ylabel('Height')
plt.show()

# %%
X = Data[['Age', 'Height', 'Frequency_of_Consuming_Vegetables', 'Number_of_Main_Meals_Daily', 'Liquid_Intake_Daily', 'Physical_Excercise', 'Schedule_Dedicated_to_Technology' ]] #independent variable
Y = Data['Overweight_Obese_Family'] #dependent variable

# %%
X = sm.add_constant(X)

model = sm.OLS(Y,X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     Overweight_Obese_Family   R-squared:                       0.108
# Model:                                 OLS   Adj. R-squared:                  0.104
# Method:                      Least Squares   F-statistic:                     27.68
# Date:                     Tue, 01 Oct 2024   Prob (F-statistic):           4.08e-36
# Time:                             13:52:19   Log-Likelihood:                -597.80
# No. Observations:                     1610   AIC:                             1212.
# Df Residuals:                         1602   BIC:                             1255.
# Df Model:                                7
# Covariance Type:                 nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
column_of_interests = ['Age', 'Height', 'Frequency_of_Consuming_Vegetables', 'Number_of_Main_Meals_Daily', 'Liquid_Intake_Daily', 'Physical_Excercise', 'Schedule_Dedicated_to_Technology']
for column in column_of_interests:
    sns.barplot(x=column, y='Overweight_Obese_Family', data = Data)
    plt.title('Overweight_Obese_Family vs Age, Height, Frequency_of_Consuming_Vegetables, Number_of_Main_Meals_Daily, Liquid_Intake_Daily, Physical_Excercise, Schedule_Dedicated_to_Technology')
    plt.show()
